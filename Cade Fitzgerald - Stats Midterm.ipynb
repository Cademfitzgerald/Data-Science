# %% [markdown]
# <a href="https://colab.research.google.com/github/Cademfitzgerald/Data-Science/blob/main/Cade%20Fitzgerald%20-%20Stats%20Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STA 2023 Midterm Project
#
# Directions:
#
# *   Use any and all resources available to you
# *   Comment and explain the code
# *   Answer the questions to the best of your abilities
# *   There are no points for pain: ask for help
#
# Save this notebook to your GitHub and submit the link.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Getting your data
#
# Create a google form to input your data.
# Follow the same method as [Lab 5](https://colab.research.google.com/drive/1zYvyhrz2wVnJXlZqj_PpxOxplfS3LN9Y?usp=sharing).

# %%
import pandas as pd
def get_database(url): # This function loads the google spreadsheet
    url_head = "https://docs.google.com/spreadsheets/d/"
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5]
    sheet_name = "1"
    url_csv = url_head + url_body + url_foot + sheet_name
    df = pd.read_csv(url_csv, sep=',', skiprows=0)
    return df

# %% [markdown]
# Put your form url here:
# https://docs.google.com/spreadsheets/d/

# %%
url = 'https://docs.google.com/spreadsheets/d/1v3iYNA9537B3C86AefSlewpDBNhchzV6appmE4FutGs/edit?resourcekey=undefined#gid=1860065639'

# %%
#Inputing data from a google form to show real data

# %%
data = get_database(url)

# %%
c = np.array([12,6,8,20,15])
d = np.array([17,4,9,23,29])

# %% [markdown]
# Plot your data points

# %%
plt.title("Circle Diameter vs Circumference")

plt.xlabel("Circumference")
plt.ylabel("Diameter")

plt.plot(c,d,'g.');

# %%
#This is a graph showing the diameter in relation to the circumference

# %% [markdown]
# ## Part 2: Linear Fit
#
# Follow the steps in the [Linear Fit notebook]() to run a linear fit on your data.

# %%
m_guess = 0
b_guess = 0

# %%
m_guess * c + b_guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_guess = m_guess * c + b_guess

# %%
y_guess - d
# Out:
# array([-17,  -4,  -9, -23, -29])

# %%
np.sum((y_guess - d)**2)
# Out:
# 1756

# %%
loss = np.sum((y_guess - d)**2)

# %%
best_loss_so_far = 10000000000000
m_best = 0
b_best = 0

for m_guess in np.linspace(-100,100,100):
  for b_guess in np.linspace(-100,100,100):

    y_guess = m_guess * c + b_guess

    loss = np.sum((y_guess - d)**2)

    if loss < best_loss_so_far:
      m_best = m_guess
      b_best = b_guess
      best_loss_so_far = loss

print("Found better fit:")
print(m_best,b_best,loss)
# Out:
# Found better fit:
# 1.0101010101010104 5.050505050505052 9706356.0

# %%
#This is usinga double for loop to find the best guess possible without having the thousands of guesses showing but only the correct best guess

# %% [markdown]
# Plot the line of best fit:
#
# Use blue dots for the collected data and a red line for the estimate.

# %%
plt.title('Linear Fit of Circles')

plt.xlabel('Diameter')
plt.ylabel('Circumference')

# Plot the collected data
plt.plot(c,d, label='Observations')

y_estimate = 14

# Plot the line of best fit
plt.plot(c,d, label=f'Estimate: $y = {2} x + {1}$')

plt.legend();

# %%
#How to plot and show the datt collected with a key to help people better understand the data presented to them

# %% [markdown]
# The estimated relationship is:
#
# $C = ? D + ?$

# %%
# As the diameter increases so does the circumference

# %% [markdown]
# ## Part 3: Interpretation
#
# Answer the questions in text cells

# %% [markdown]
# #### Question 1:
#
# What do $m$ and $b$ represent in these equations?

# %% [markdown]
# The slope and the y intercept

# %% [markdown]
# #### Question 2:
#
# Guess what the correct values $m$ and $b$ should be.

# %% [markdown]
# m=2 b=1

# %% [markdown]
# #### Question 3:
#
# Does it make sense to include $b$ in the parameters?

# %% [markdown]
# Yes because it is part of the equation

# %% [markdown]
# ## Bonus:
#
# These problems are extra credit. You may use any resources, but be sure to explain your code.

# %% [markdown]
# #### Bonus 1: Plot the squared errors from your line of best fit

# %%
plt.title("Fit Errors")

plt.xlabel("Diameter")
plt.ylabel("Squared Error")

squared_error = ...

plt.plot(..., 'b.', label = "Errors")

plt.legend();

# %% [markdown]
# #### Bonus 2: Plot the errors as a histogram

# %%
plt.title("Errors")

...

# %% [markdown]
# What distribution does this histogram look like?

# %% [markdown]
# #### Bonus 3: Find the circle with the largest error.
# Hint: use np.max

# %%
largest_error = ...

# %% [markdown]
# #### Bonus 4: Remove the circles with the 2 largest errors and run the fit again.

# %%
...

# %% [markdown]
# What is the difference in your error?

# %% [markdown]
# #### Bonus 5: Find and explain a better method of fitting this data
